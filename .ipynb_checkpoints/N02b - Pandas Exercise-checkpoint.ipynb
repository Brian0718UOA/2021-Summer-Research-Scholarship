# %% [markdown]
# # Civil 774 - Smart Infrastructure Analytics
#
# ## Pandas exercise

# %% [markdown]
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ### Step 2. Load the `nz_cars.csv` data in the Data folder, use `OBJECTID` as index

# %%
df = pd.read_csv('NZ_cars.csv', index_col = ["OBJECTID"])
print(df)
# Out:
#          BASIC_COLOUR      BODY_TYPE  CC_RATING  FIRST_NZ_REGISTRATION_YEAR  \
# OBJECTID
# 3001            WHITE         SALOON       1971                        1979
# 3002             GOLD      HATCHBACK       1769                        2005
# 3003              RED         SALOON       5665                        2005
# 3004             BLUE      HATCHBACK       1796                        2003
# 3005           SILVER      HATCHBACK       1796                        2003
# ...               ...            ...        ...                         ...
# 3996           SILVER         SALOON       3828                        2007
# 3997           YELLOW         SALOON        995                        1982
# 3998             BLUE         SALOON       2000                        1991
# 3999            BLACK  STATION WAGON       2261                        2007
# 4000           SILVER  STATION WAGON       1990                        2005
#
#           FIRST_NZ_REGISTRATION_MONTH  GROSS_VEHICLE_MASS IMPORT_STATUS  \
# OBJECTID
# 3001                                5                   0           NEW
# 3002                                5                1245           NEW
# 3003                                9                2129           NEW
# 3004                               10                1690           NEW
# 3005                                6                1640           NEW
# ...                               ...                 ...           ...
# 3996                                3                   0           NEW
# 3997                                6                   0           NEW
# 3998                                7                   0           NEW
# 3999                                6                1862           NEW
# 4000                               12                1645          USED
#
#          INDUSTRY_CLASS        MAKE      MODEL  ...       NZ_ASSEMBLED  \
# OBJECTID                                        ...
# 3001            PRIVATE     PEUGEOT        504  ...            UNKNOWN
# 3002            PRIVATE      NISSAN     PULSAR  ...  IMPORTED BUILT-UP
# 3003            PRIVATE      HOLDEN  COMMODORE  ...  IMPORTED BUILT-UP
# 3004            PRIVATE      HOLDEN      ASTRA  ...  IMPORTED BUILT-UP
# 3005            PRIVATE      HOLDEN      ASTRA  ...  IMPORTED BUILT-UP
# ...                 ...         ...        ...  ...                ...
# 3996            PRIVATE  MITSUBISHI        380  ...  IMPORTED BUILT-UP
# 3997            PRIVATE     LEYLAND       MINI  ...            UNKNOWN
# 3998            PRIVATE        FORD    TELSTAR  ...            UNKNOWN
# 3999            PRIVATE       MAZDA     MAZDA6  ...  IMPORTED BUILT-UP
# 4000            PRIVATE       MAZDA     ATENZA  ...  IMPORTED BUILT-UP
#
#           ORIGINAL_COUNTRY  POWER_RATING PREVIOUS_COUNTRY  \
# OBJECTID
# 3001             NOT KNOWN             0             NONE
# 3002        UNITED KINGDOM            92             NONE
# 3003             AUSTRALIA           245             NONE
# 3004               GERMANY            85             NONE
# 3005               GERMANY            85             NONE
# ...                    ...           ...              ...
# 3996             AUSTRALIA           175             NONE
# 3997             NOT KNOWN             0             NONE
# 3998                 JAPAN             0             NONE
# 3999                 JAPAN           122             NONE
# 4000                 JAPAN             0            JAPAN
#
#                       SUBMODEL                    TLA TRANSMISSION_TYPE  \
# OBJECTID
# 3001                       NaN               AUCKLAND               NaN
# 3002            1.8 HATCH AUTO               AUCKLAND       5-GEAR AUTO
# 3003                 S V8 AUTO               AUCKLAND       4-GEAR AUTO
# 3004        CD HATCH 1.8L AUTO               AUCKLAND       4-GEAR AUTO
# 3005       CITY HATCH 1.8L MAN               AUCKLAND     5-GEAR MANUAL
# ...                        ...                    ...               ...
# 3996              3.8P SEDAN A     WHANGAREI DISTRICT       5-GEAR AUTO
# 3997                       NaN       WAIKATO DISTRICT               NaN
# 3998                       NaN     WHAKATANE DISTRICT               NaN
# 3999      WAGON GSX 2.3 5 AUTO  NEW PLYMOUTH DISTRICT       5-GEAR AUTO
# 4000                       NaN               AUCKLAND               NaN
#
#                VEHICLE_TYPE      VEHICLE_USAGE VEHICLE_YEAR
# OBJECTID
# 3001      PASSENGER CAR/VAN  PRIVATE PASSENGER         1979
# 3002      PASSENGER CAR/VAN  PRIVATE PASSENGER         2005
# 3003      PASSENGER CAR/VAN  PRIVATE PASSENGER         2005
# 3004      PASSENGER CAR/VAN  PRIVATE PASSENGER         2003
# 3005      PASSENGER CAR/VAN  PRIVATE PASSENGER         2003
# ...                     ...                ...          ...
# 3996      PASSENGER CAR/VAN  PRIVATE PASSENGER         2007
# 3997      PASSENGER CAR/VAN  PRIVATE PASSENGER         1982
# 3998      PASSENGER CAR/VAN  PRIVATE PASSENGER         1991
# 3999      PASSENGER CAR/VAN  PRIVATE PASSENGER         2007
# 4000      PASSENGER CAR/VAN  PRIVATE PASSENGER         2002
#
# [1000 rows x 23 columns]

# %% [markdown]
# ### Step 3. See the first 5 entries

# %%
df.head()
# Out:
#          BASIC_COLOUR  BODY_TYPE  CC_RATING  FIRST_NZ_REGISTRATION_YEAR  \
# OBJECTID
# 3001            WHITE     SALOON       1971                        1979
# 3002             GOLD  HATCHBACK       1769                        2005
# 3003              RED     SALOON       5665                        2005
# 3004             BLUE  HATCHBACK       1796                        2003
# 3005           SILVER  HATCHBACK       1796                        2003
#
#           FIRST_NZ_REGISTRATION_MONTH  GROSS_VEHICLE_MASS IMPORT_STATUS  \
# OBJECTID
# 3001                                5                   0           NEW
# 3002                                5                1245           NEW
# 3003                                9                2129           NEW
# 3004                               10                1690           NEW
# 3005                                6                1640           NEW
#
#          INDUSTRY_CLASS     MAKE      MODEL  ...       NZ_ASSEMBLED  \
# OBJECTID                                     ...
# 3001            PRIVATE  PEUGEOT        504  ...            UNKNOWN
# 3002            PRIVATE   NISSAN     PULSAR  ...  IMPORTED BUILT-UP
# 3003            PRIVATE   HOLDEN  COMMODORE  ...  IMPORTED BUILT-UP
# 3004            PRIVATE   HOLDEN      ASTRA  ...  IMPORTED BUILT-UP
# 3005            PRIVATE   HOLDEN      ASTRA  ...  IMPORTED BUILT-UP
#
#           ORIGINAL_COUNTRY  POWER_RATING PREVIOUS_COUNTRY  \
# OBJECTID
# 3001             NOT KNOWN             0             NONE
# 3002        UNITED KINGDOM            92             NONE
# 3003             AUSTRALIA           245             NONE
# 3004               GERMANY            85             NONE
# 3005               GERMANY            85             NONE
#
#                      SUBMODEL       TLA TRANSMISSION_TYPE       VEHICLE_TYPE  \
# OBJECTID
# 3001                      NaN  AUCKLAND               NaN  PASSENGER CAR/VAN
# 3002           1.8 HATCH AUTO  AUCKLAND       5-GEAR AUTO  PASSENGER CAR/VAN
# 3003                S V8 AUTO  AUCKLAND       4-GEAR AUTO  PASSENGER CAR/VAN
# 3004       CD HATCH 1.8L AUTO  AUCKLAND       4-GEAR AUTO  PASSENGER CAR/VAN
# 3005      CITY HATCH 1.8L MAN  AUCKLAND     5-GEAR MANUAL  PASSENGER CAR/VAN
#
#               VEHICLE_USAGE VEHICLE_YEAR
# OBJECTID
# 3001      PRIVATE PASSENGER         1979
# 3002      PRIVATE PASSENGER         2005
# 3003      PRIVATE PASSENGER         2005
# 3004      PRIVATE PASSENGER         2003
# 3005      PRIVATE PASSENGER         2003
#
# [5 rows x 23 columns]

# %% [markdown]
# ### Step 4. See the first 25 entries

# %%
df.head(25)
# Out:
#          BASIC_COLOUR          BODY_TYPE  CC_RATING  \
# OBJECTID
# 3001            WHITE             SALOON       1971
# 3002             GOLD          HATCHBACK       1769
# 3003              RED             SALOON       5665
# 3004             BLUE          HATCHBACK       1796
# 3005           SILVER          HATCHBACK       1796
# 3006             BLUE             SALOON       1796
# 3007           SILVER             SALOON       2946
# 3008            BLACK      STATION WAGON       1968
# 3009           SILVER             SALOON       1800
# 3010             GOLD             SALOON       1725
# 3011             GOLD         MOTORCYCLE        996
# 3012           SILVER             SALOON       3498
# 3013              RED          HATCHBACK       1997
# 3014           SILVER      STATION WAGON       1990
# 3015           SILVER          HATCHBACK       1769
# 3016           SILVER      STATION WAGON       2362
# 3017             GREY             SALOON       3498
# 3018           SILVER          HATCHBACK       1330
# 3019           SILVER             SALOON       3497
# 3020              RED          HATCHBACK       1295
# 3021           SILVER          LIGHT VAN       3378
# 3022           SILVER      STATION WAGON       2488
# 3023            WHITE      STATION WAGON       3954
# 3024              RED             SALOON       2000
# 3025             GREY  FLAT-DECK TRAILER          0
#
#           FIRST_NZ_REGISTRATION_YEAR  FIRST_NZ_REGISTRATION_MONTH  \
# OBJECTID
# 3001                            1979                            5
# 3002                            2005                            5
# 3003                            2005                            9
# 3004                            2003                           10
# 3005                            2003                            6
# 3006                            2003                            7
# 3007                            2005                            7
# 3008                            2012                            4
# 3009                            1990                            5
# 3010                            1973                            5
# 3011                            2009                            1
# 3012                            2006                            4
# 3013                            2010                            1
# 3014                            2009                           11
# 3015                            2005                            3
# 3016                            2009                           12
# 3017                            2006                            3
# 3018                            2007                           10
# 3019                            2006                            3
# 3020                            1989                            8
# 3021                            2005                            7
# 3022                            2005                            9
# 3023                            2007                            8
# 3024                            1989                            4
# 3025                            2004                           10
#
#           GROSS_VEHICLE_MASS IMPORT_STATUS INDUSTRY_CLASS        MAKE  \
# OBJECTID
# 3001                       0           NEW        PRIVATE     PEUGEOT
# 3002                    1245           NEW        PRIVATE      NISSAN
# 3003                    2129           NEW        PRIVATE      HOLDEN
# 3004                    1690           NEW        PRIVATE      HOLDEN
# 3005                    1640           NEW        PRIVATE      HOLDEN
# 3006                    1690           NEW        PRIVATE      HOLDEN
# 3007                       0           NEW        PRIVATE     PEUGEOT
# 3008                    2185           NEW        PRIVATE        AUDI
# 3009                       0           NEW        UNKNOWN      SUBARU
# 3010                       0           NEW        PRIVATE     SUNBEAM
# 3011                       0          USED        PRIVATE       HONDA
# 3012                       0           NEW        PRIVATE      NISSAN
# 3013                    1921           NEW        PRIVATE     PEUGEOT
# 3014                    1815          USED        PRIVATE     PEUGEOT
# 3015                    1235           NEW        PRIVATE      NISSAN
# 3016                    1875          USED        PRIVATE      TOYOTA
# 3017                       0           NEW        PRIVATE      NISSAN
# 3018                    1275          USED        PRIVATE       HONDA
# 3019                    2095           NEW        PRIVATE  MITSUBISHI
# 3020                       0           NEW        PRIVATE      TOYOTA
# 3021                    2390          USED        PRIVATE      TOYOTA
# 3022                    2913           NEW        PRIVATE      NISSAN
# 3023                    3000           NEW        PRIVATE      NISSAN
# 3024                       0           NEW        UNKNOWN       HONDA
# 3025                    3000           NEW        PRIVATE     TRAILER
#
#                 MODEL  ...        NZ_ASSEMBLED  ORIGINAL_COUNTRY  \
# OBJECTID               ...
# 3001              504  ...             UNKNOWN         NOT KNOWN
# 3002           PULSAR  ...   IMPORTED BUILT-UP    UNITED KINGDOM
# 3003        COMMODORE  ...   IMPORTED BUILT-UP         AUSTRALIA
# 3004            ASTRA  ...   IMPORTED BUILT-UP           GERMANY
# 3005            ASTRA  ...   IMPORTED BUILT-UP           GERMANY
# 3006            ASTRA  ...   IMPORTED BUILT-UP           GERMANY
# 3007              407  ...   IMPORTED BUILT-UP            FRANCE
# 3008               Q3  ...   IMPORTED BUILT-UP           GERMANY
# 3009           LEGACY  ...             UNKNOWN             JAPAN
# 3010          SCEPTRE  ...             UNKNOWN         NOT KNOWN
# 3011               XL  ...   IMPORTED BUILT-UP             JAPAN
# 3012           MAXIMA  ...   IMPORTED BUILT-UP             JAPAN
# 3013              308  ...   IMPORTED BUILT-UP            FRANCE
# 3014              307  ...   IMPORTED BUILT-UP            FRANCE
# 3015           PULSAR  ...   IMPORTED BUILT-UP    UNITED KINGDOM
# 3016            IPSUM  ...   IMPORTED BUILT-UP             JAPAN
# 3017           MAXIMA  ...   IMPORTED BUILT-UP             JAPAN
# 3018              FIT  ...   IMPORTED BUILT-UP             JAPAN
# 3019         DIAMANTE  ...   IMPORTED BUILT-UP         AUSTRALIA
# 3020          STARLET  ...             UNKNOWN             JAPAN
# 3021      LANDCRUISER  ...   IMPORTED BUILT-UP             JAPAN
# 3022       PATHFINDER  ...   IMPORTED BUILT-UP             SPAIN
# 3023       PATHFINDER  ...   IMPORTED BUILT-UP             SPAIN
# 3024          PRELUDE  ...             UNKNOWN             JAPAN
# 3025         HOMEMADE  ...  NZ ASSEMBLED/BUILT       NEW ZEALAND
#
#           POWER_RATING PREVIOUS_COUNTRY             SUBMODEL  \
# OBJECTID
# 3001                 0             NONE                  NaN
# 3002                92             NONE       1.8 HATCH AUTO
# 3003               245             NONE            S V8 AUTO
# 3004                85             NONE   CD HATCH 1.8L AUTO
# 3005                85             NONE  CITY HATCH 1.8L MAN
# 3006                85             NONE  CITY SEDAN 1.8L MAN
# 3007               155             NONE   V6 3.0 5DR 6SP A P
# 3008               130             NONE   2.0 TDI Q S TRONIC
# 3009                 0             NONE               DL 1.8
# 3010                 0             NONE                  NaN
# 3011                 0        AUSTRALIA                1000V
# 3012               170             NONE        3.5 PETROL ST
# 3013               100             NONE             HDI AUTO
# 3014                 0            JAPAN                   SW
# 3015                92             NONE     1.8 LS HATCH MAN
# 3016                 0            JAPAN                 240S
# 3017               170             NONE   3.5 PETROL TI LTHR
# 3018                 0            JAPAN                  NaN
# 3019               163             NONE    3.5P VR-X SEDAN A
# 3020                 0             NONE                1.3XL
# 3021                 0            JAPAN             PRADO TX
# 3022               128             NONE      2.5 4WD ST AUTO
# 3023               198             NONE      4.0 4WD TI AUTO
# 3024                 0             NONE                  4WS
# 3025                 0             NONE                  NaN
#
#                                      TLA TRANSMISSION_TYPE       VEHICLE_TYPE  \
# OBJECTID
# 3001                            AUCKLAND               NaN  PASSENGER CAR/VAN
# 3002                            AUCKLAND       5-GEAR AUTO  PASSENGER CAR/VAN
# 3003                            AUCKLAND       4-GEAR AUTO  PASSENGER CAR/VAN
# 3004                            AUCKLAND       4-GEAR AUTO  PASSENGER CAR/VAN
# 3005                            AUCKLAND     5-GEAR MANUAL  PASSENGER CAR/VAN
# 3006                  WHANGANUI DISTRICT     5-GEAR MANUAL  PASSENGER CAR/VAN
# 3007                         NAPIER CITY       6-GEAR AUTO  PASSENGER CAR/VAN
# 3008                            AUCKLAND       7-GEAR AUTO  PASSENGER CAR/VAN
# 3009                  WHANGAREI DISTRICT               NaN  PASSENGER CAR/VAN
# 3010                    HURUNUI DISTRICT               NaN  PASSENGER CAR/VAN
# 3011                         NAPIER CITY               NaN         MOTORCYCLE
# 3012               KAPITI COAST DISTRICT       6-GEAR AUTO  PASSENGER CAR/VAN
# 3013                        PORIRUA CITY       6-GEAR AUTO  PASSENGER CAR/VAN
# 3014                            AUCKLAND               NaN  PASSENGER CAR/VAN
# 3015      WESTERN BAY OF PLENTY DISTRICT     5-GEAR MANUAL  PASSENGER CAR/VAN
# 3016                     WELLINGTON CITY               NaN  PASSENGER CAR/VAN
# 3017                         NAPIER CITY       6-GEAR AUTO  PASSENGER CAR/VAN
# 3018                        DUNEDIN CITY               NaN  PASSENGER CAR/VAN
# 3019                       TAURANGA CITY       5-GEAR AUTO  PASSENGER CAR/VAN
# 3020                     WELLINGTON CITY               NaN  PASSENGER CAR/VAN
# 3021                            AUCKLAND               NaN  PASSENGER CAR/VAN
# 3022                  WHANGAREI DISTRICT       5-GEAR AUTO  PASSENGER CAR/VAN
# 3023                  WHANGAREI DISTRICT       5-GEAR AUTO  PASSENGER CAR/VAN
# 3024               PALMERSTON NORTH CITY               NaN  PASSENGER CAR/VAN
# 3025                       HAMILTON CITY               NaN    TRAILER/CARAVAN
#
#               VEHICLE_USAGE VEHICLE_YEAR
# OBJECTID
# 3001      PRIVATE PASSENGER         1979
# 3002      PRIVATE PASSENGER         2005
# 3003      PRIVATE PASSENGER         2005
# 3004      PRIVATE PASSENGER         2003
# 3005      PRIVATE PASSENGER         2003
# 3006      PRIVATE PASSENGER         2003
# 3007      PRIVATE PASSENGER         2005
# 3008      PRIVATE PASSENGER         2012
# 3009      PRIVATE PASSENGER         1990
# 3010      PRIVATE PASSENGER         1973
# 3011      PRIVATE PASSENGER         1998
# 3012      PRIVATE PASSENGER         2006
# 3013      PRIVATE PASSENGER         2010
# 3014      PRIVATE PASSENGER         2003
# 3015      PRIVATE PASSENGER         2005
# 3016      PRIVATE PASSENGER         2002
# 3017      PRIVATE PASSENGER         2006
# 3018      PRIVATE PASSENGER         2003
# 3019      PRIVATE PASSENGER         2006
# 3020      PRIVATE PASSENGER         1989
# 3021      PRIVATE PASSENGER         2002
# 3022      PRIVATE PASSENGER         2005
# 3023      PRIVATE PASSENGER         2007
# 3024      PRIVATE PASSENGER         1989
# 3025            OTHER GOODS         2004
#
# [25 rows x 23 columns]

# %% [markdown]
# ### Step 5. See the last 10 entries

# %%
df.tail(10)
# Out:
#          BASIC_COLOUR      BODY_TYPE  CC_RATING  FIRST_NZ_REGISTRATION_YEAR  \
# OBJECTID
# 3991             BLUE      HATCHBACK       1598                        1991
# 3992           SILVER  STATION WAGON       2261                        2007
# 3993             BLUE      HATCHBACK       1339                        2006
# 3994           SILVER  STATION WAGON       1490                        2006
# 3995             GREY  STATION WAGON       1896                        2009
# 3996           SILVER         SALOON       3828                        2007
# 3997           YELLOW         SALOON        995                        1982
# 3998             BLUE         SALOON       2000                        1991
# 3999            BLACK  STATION WAGON       2261                        2007
# 4000           SILVER  STATION WAGON       1990                        2005
#
#           FIRST_NZ_REGISTRATION_MONTH  GROSS_VEHICLE_MASS IMPORT_STATUS  \
# OBJECTID
# 3991                                7                   0           NEW
# 3992                                7                1862           NEW
# 3993                                5                1490           NEW
# 3994                                2                1335          USED
# 3995                                2                   0           NEW
# 3996                                3                   0           NEW
# 3997                                6                   0           NEW
# 3998                                7                   0           NEW
# 3999                                6                1862           NEW
# 4000                               12                1645          USED
#
#          INDUSTRY_CLASS        MAKE    MODEL  ...       NZ_ASSEMBLED  \
# OBJECTID                                      ...
# 3991            PRIVATE       MAZDA   ASTINA  ...            UNKNOWN
# 3992            PRIVATE       MAZDA   MAZDA6  ...  IMPORTED BUILT-UP
# 3993            PRIVATE       HONDA     JAZZ  ...  IMPORTED BUILT-UP
# 3994            PRIVATE      SUZUKI   CULTUS  ...  IMPORTED BUILT-UP
# 3995            PRIVATE       SKODA    FABIA  ...  IMPORTED BUILT-UP
# 3996            PRIVATE  MITSUBISHI      380  ...  IMPORTED BUILT-UP
# 3997            PRIVATE     LEYLAND     MINI  ...            UNKNOWN
# 3998            PRIVATE        FORD  TELSTAR  ...            UNKNOWN
# 3999            PRIVATE       MAZDA   MAZDA6  ...  IMPORTED BUILT-UP
# 4000            PRIVATE       MAZDA   ATENZA  ...  IMPORTED BUILT-UP
#
#           ORIGINAL_COUNTRY  POWER_RATING PREVIOUS_COUNTRY  \
# OBJECTID
# 3991                 JAPAN             0             NONE
# 3992                 JAPAN           122             NONE
# 3993                 JAPAN            61             NONE
# 3994                 JAPAN             0            JAPAN
# 3995        CZECH REPUBLIC            77             NONE
# 3996             AUSTRALIA           175             NONE
# 3997             NOT KNOWN             0             NONE
# 3998                 JAPAN             0             NONE
# 3999                 JAPAN           122             NONE
# 4000                 JAPAN             0            JAPAN
#
#                       SUBMODEL                    TLA      TRANSMISSION_TYPE  \
# OBJECTID
# 3991                  323  GLX        SELWYN DISTRICT                    NaN
# 3992      WAGON GSX 2.3 5 AUTO        UPPER HUTT CITY            5-GEAR AUTO
# 3993         1.3I 5D CVT HATCH               AUCKLAND  CONTINUOUSLY VARIABLE
# 3994                       NaN           DUNEDIN CITY                    NaN
# 3995             1.9 TDI COMBI               AUCKLAND          5-GEAR MANUAL
# 3996              3.8P SEDAN A     WHANGAREI DISTRICT            5-GEAR AUTO
# 3997                       NaN       WAIKATO DISTRICT                    NaN
# 3998                       NaN     WHAKATANE DISTRICT                    NaN
# 3999      WAGON GSX 2.3 5 AUTO  NEW PLYMOUTH DISTRICT            5-GEAR AUTO
# 4000                       NaN               AUCKLAND                    NaN
#
#                VEHICLE_TYPE      VEHICLE_USAGE VEHICLE_YEAR
# OBJECTID
# 3991      PASSENGER CAR/VAN  PRIVATE PASSENGER         1991
# 3992      PASSENGER CAR/VAN  PRIVATE PASSENGER         2007
# 3993      PASSENGER CAR/VAN  PRIVATE PASSENGER         2006
# 3994      PASSENGER CAR/VAN  PRIVATE PASSENGER         2002
# 3995      PASSENGER CAR/VAN  PRIVATE PASSENGER         2009
# 3996      PASSENGER CAR/VAN  PRIVATE PASSENGER         2007
# 3997      PASSENGER CAR/VAN  PRIVATE PASSENGER         1982
# 3998      PASSENGER CAR/VAN  PRIVATE PASSENGER         1991
# 3999      PASSENGER CAR/VAN  PRIVATE PASSENGER         2007
# 4000      PASSENGER CAR/VAN  PRIVATE PASSENGER         2002
#
# [10 rows x 23 columns]

# %% [markdown]
# ### Step 6. What is the number of observations in the dataset?

# %%
len(df.index)
# Out:
# 1000

# %% [markdown]
# ### Step 7. What is the number of columns in the dataset?

# %%
len(df.columns)
# Out:
# 23

# %% [markdown]
# ### Step 8. Print the name of all the columns.

# %%
print(df.columns)
# Out:
# Index(['BASIC_COLOUR', 'BODY_TYPE', 'CC_RATING', 'FIRST_NZ_REGISTRATION_YEAR',
#        'FIRST_NZ_REGISTRATION_MONTH', 'GROSS_VEHICLE_MASS', 'IMPORT_STATUS',
#        'INDUSTRY_CLASS', 'MAKE', 'MODEL', 'MOTIVE_POWER', 'NUMBER_OF_AXLES',
#        'NUMBER_OF_SEATS', 'NZ_ASSEMBLED', 'ORIGINAL_COUNTRY', 'POWER_RATING',
#        'PREVIOUS_COUNTRY', 'SUBMODEL', 'TLA', 'TRANSMISSION_TYPE',
#        'VEHICLE_TYPE', 'VEHICLE_USAGE', 'VEHICLE_YEAR'],
#       dtype='object')

# %% [markdown]
# ### Step 9. What is the data type of each column?

# %%
df.dtypes
# Out:
# BASIC_COLOUR                   object
# BODY_TYPE                      object
# CC_RATING                       int64
# FIRST_NZ_REGISTRATION_YEAR      int64
# FIRST_NZ_REGISTRATION_MONTH     int64
# GROSS_VEHICLE_MASS              int64
# IMPORT_STATUS                  object
# INDUSTRY_CLASS                 object
# MAKE                           object
# MODEL                          object
# MOTIVE_POWER                   object
# NUMBER_OF_AXLES                 int64
# NUMBER_OF_SEATS                 int64
# NZ_ASSEMBLED                   object
# ORIGINAL_COUNTRY               object
# POWER_RATING                    int64
# PREVIOUS_COUNTRY               object
# SUBMODEL                       object
# TLA                            object
# TRANSMISSION_TYPE              object
# VEHICLE_TYPE                   object
# VEHICLE_USAGE                  object
# VEHICLE_YEAR                    int64
# dtype: object

# %% [markdown]
# ### Step 10. Print only the MAKE column

# %%
print(df["MAKE"])
# Out:
# OBJECTID
# 3001       PEUGEOT
# 3002        NISSAN
# 3003        HOLDEN
# 3004        HOLDEN
# 3005        HOLDEN
#            ...
# 3996    MITSUBISHI
# 3997       LEYLAND
# 3998          FORD
# 3999         MAZDA
# 4000         MAZDA
# Name: MAKE, Length: 1000, dtype: object

# %% [markdown]
# ### Step 11. How many different car makes are in this dataset?

# %%
df.MAKE.nunique()
# Out:
# 70

# %% [markdown]
# ### Step 12. What is the most frequent make of the cars?

# %%
make_count = df.MAKE.value_counts()
print(make_count)

highest_make = make_count.index[0]
print('\nMost frequent make of cars is', highest_make)
# Out:
# TOYOTA       158
# MAZDA        140
# NISSAN       105
# FORD          87
# HONDA         83
#             ...
# CARAVAN        1
# REID           1
# MOPED          1
# PIAGGIO        1
# SSANGYONG      1
# Name: MAKE, Length: 70, dtype: int64
#
# Most frequent make of cars is TOYOTA

# %% [markdown]
# ### Step 13. Summarise the DataFrame.

# %%
df.describe()
# Out:
#           CC_RATING  FIRST_NZ_REGISTRATION_YEAR  FIRST_NZ_REGISTRATION_MONTH  \
# count   1000.000000                  1000.00000                  1000.000000
# mean    2162.729000                  2002.12700                     6.437000
# std     1342.608973                     8.61261                     3.299533
# min        0.000000                  1947.00000                     1.000000
# 25%     1495.250000                  2004.00000                     4.000000
# 50%     1998.000000                  2005.00000                     7.000000
# 75%     2499.250000                  2007.00000                     9.000000
# max    11045.000000                  2012.00000                    12.000000
#
#        GROSS_VEHICLE_MASS  NUMBER_OF_AXLES  NUMBER_OF_SEATS  POWER_RATING  \
# count         1000.000000      1000.000000       1000.00000    1000.00000
# mean          1757.147000         1.006000          4.46400      48.27500
# std           2405.467315         1.010438          3.85533      73.62195
# min              0.000000         0.000000          0.00000       0.00000
# 25%            923.750000         0.000000          4.00000       0.00000
# 50%           1665.000000         1.000000          5.00000       0.00000
# 75%           2100.000000         2.000000          5.00000     103.00000
# max          29000.000000         4.000000         64.00000     999.00000
#
#        VEHICLE_YEAR
# count   1000.000000
# mean    1999.463000
# std        9.453359
# min     1930.000000
# 25%     1996.000000
# 50%     2003.000000
# 75%     2006.000000
# max     2012.000000

# %% [markdown]
# ### Step 14. Summarise only the MAKE column

# %%
df.MAKE.describe()
# Out:
# count       1000
# unique        70
# top       TOYOTA
# freq         158
# Name: MAKE, dtype: object

# %% [markdown]
# ### Step 15. What is the mean CC_RATING of cars?

# %%
df['CC_RATING'].mean()
# Out:
# 2162.729

# %% [markdown]
# ### Step 16. What is the CC_RATING with least occurrence?

# %%
cc_rating_count = df.CC_RATING.value_counts()
lowest_freq_CC = cc_rating_count.index[-1]
print('\nCC_RATING with least occurence is', lowest_freq_CC)
# Out:
# CC_RATING with least occurence is 5100

# %% [markdown]
# ## Step 17. Sort the cars ascending by CC_RATING, then FIRST_NZ_REGISTRATION_YEAR

# %%
df.sort_values("CC_RATING", axis = 0, ascending = True, inplace = True, na_position = 'last')
df.sort_values("FIRST_NZ_REGISTRATION_YEAR", axis = 0, ascending = True, inplace = True, na_position = 'last')
print(df)
# Out:
#          BASIC_COLOUR      BODY_TYPE  CC_RATING  FIRST_NZ_REGISTRATION_YEAR  \
# OBJECTID
# 3526              RED     SPORTS CAR       1600                        1947
# 3648            WHITE         SALOON       1192                        1962
# 3758            GREEN         SALOON       1285                        1966
# 3442             BLUE         SALOON       3284                        1967
# 3884            WHITE         SALOON       2553                        1970
# ...               ...            ...        ...                         ...
# 3874            BLACK         SALOON       1796                        2012
# 3445           SILVER  STATION WAGON       1794                        2012
# 3349             BLUE      HATCHBACK       2260                        2012
# 3008            BLACK  STATION WAGON       1968                        2012
# 3610           SILVER  STATION WAGON       1490                        2012
#
#           FIRST_NZ_REGISTRATION_MONTH  GROSS_VEHICLE_MASS IMPORT_STATUS  \
# OBJECTID
# 3526                               11                   0           NEW
# 3648                                6                   0           NEW
# 3758                                8                   0        RE-REG
# 3442                                6                   0           NEW
# 3884                               12                   0           NEW
# ...                               ...                 ...           ...
# 3874                                2                2185           NEW
# 3445                                4                1425          USED
# 3349                                7                1555          USED
# 3008                                4                2185           NEW
# 3610                                3                1515          USED
#
#          INDUSTRY_CLASS           MAKE    MODEL  ...        NZ_ASSEMBLED  \
# OBJECTID                                         ...
# 3526            UNKNOWN          ROVER       16  ...             UNKNOWN
# 3648            PRIVATE     VOLKSWAGEN      NaN  ...             UNKNOWN
# 3758            PRIVATE     VOLKSWAGEN     1300  ...  NZ ASSEMBLED/BUILT
# 3442            PRIVATE           FORD        A  ...             UNKNOWN
# 3884            PRIVATE           FORD   ZODIAC  ...             UNKNOWN
# ...                 ...            ...      ...  ...                 ...
# 3874            PRIVATE  MERCEDES-BENZ        E  ...   IMPORTED BUILT-UP
# 3445            PRIVATE         TOYOTA  COROLLA  ...   IMPORTED BUILT-UP
# 3349            PRIVATE          MAZDA    AXELA  ...   IMPORTED BUILT-UP
# 3008            PRIVATE           AUDI       Q3  ...   IMPORTED BUILT-UP
# 3610            PRIVATE          MAZDA    AXELA  ...   IMPORTED BUILT-UP
#
#           ORIGINAL_COUNTRY  POWER_RATING PREVIOUS_COUNTRY            SUBMODEL  \
# OBJECTID
# 3526             NOT KNOWN             0             NONE                 NaN
# 3648             NOT KNOWN             0             NONE                 NaN
# 3758           NEW ZEALAND             0             NONE                 NaN
# 3442             NOT KNOWN             0             NONE                 NaN
# 3884             NOT KNOWN             0             NONE                 NaN
# ...                    ...           ...              ...                 ...
# 3874               GERMANY           150             NONE  250 CGI AVANTGARDE
# 3445                 JAPAN             0            JAPAN           FIELDER S
# 3349                 JAPAN             0            JAPAN                 NaN
# 3008               GERMANY           130             NONE  2.0 TDI Q S TRONIC
# 3610                 JAPAN             0            JAPAN                 NaN
#
#                          TLA TRANSMISSION_TYPE       VEHICLE_TYPE  \
# OBJECTID
# 3526             NELSON CITY               NaN  PASSENGER CAR/VAN
# 3648          WAIPA DISTRICT               NaN  PASSENGER CAR/VAN
# 3758                AUCKLAND               NaN  PASSENGER CAR/VAN
# 3442       HASTINGS DISTRICT               NaN  PASSENGER CAR/VAN
# 3884       HASTINGS DISTRICT               NaN  PASSENGER CAR/VAN
# ...                      ...               ...                ...
# 3874      WHANGAREI DISTRICT       7-GEAR AUTO  PASSENGER CAR/VAN
# 3445                AUCKLAND               NaN  PASSENGER CAR/VAN
# 3349                AUCKLAND               NaN  PASSENGER CAR/VAN
# 3008                AUCKLAND       7-GEAR AUTO  PASSENGER CAR/VAN
# 3610                AUCKLAND               NaN  PASSENGER CAR/VAN
#
#               VEHICLE_USAGE VEHICLE_YEAR
# OBJECTID
# 3526      PRIVATE PASSENGER         1947
# 3648      PRIVATE PASSENGER         1962
# 3758      PRIVATE PASSENGER         1966
# 3442      PRIVATE PASSENGER         1932
# 3884      PRIVATE PASSENGER         1965
# ...                     ...          ...
# 3874      PRIVATE PASSENGER         2012
# 3445      PRIVATE PASSENGER         2006
# 3349      PRIVATE PASSENGER         2005
# 3008      PRIVATE PASSENGER         2012
# 3610      PRIVATE PASSENGER         2006
#
# [1000 rows x 23 columns]

# %% [markdown]
# ## Step 18. Filter cars with CC_RATING more than 3000 only

# %%
cc_rating_3000 = df[df["CC_RATING"] > 3000]
print(cc_rating_3000)
# Out:
#          BASIC_COLOUR               BODY_TYPE  CC_RATING  \
# OBJECTID
# 3442             BLUE                  SALOON       3284
# 3271            BROWN                  SALOON       3900
# 3156            WHITE  SELF PROPELLED CARAVAN       4927
# 3098              RED                 UTILITY       4343
# 3060           YELLOW                 UTILITY       4230
# ...               ...                     ...        ...
# 3579            BLACK             CONVERTIBLE       3999
# 3828            BLACK           STATION WAGON       3597
# 3594             BLUE           STATION WAGON       3600
# 3571            WHITE  SELF PROPELLED CARAVAN       5193
# 3612           SILVER                 UTILITY       3199
#
#           FIRST_NZ_REGISTRATION_YEAR  FIRST_NZ_REGISTRATION_MONTH  \
# OBJECTID
# 3442                            1967                            6
# 3271                            1972                           11
# 3156                            1977                            6
# 3098                            1977                            9
# 3060                            1977                           10
# ...                              ...                          ...
# 3579                            2009                            6
# 3828                            2009                            1
# 3594                            2009                            1
# 3571                            2010                            1
# 3612                            2012                            6
#
#           GROSS_VEHICLE_MASS IMPORT_STATUS INDUSTRY_CLASS        MAKE  \
# OBJECTID
# 3442                       0           NEW        PRIVATE        FORD
# 3271                       0           NEW        PRIVATE        FORD
# 3156                    6909           NEW        PRIVATE     BEDFORD
# 3098                    1999           NEW        UNKNOWN    CHRYSLER
# 3060                    1999           NEW        PRIVATE      TOYOTA
# ...                      ...           ...            ...         ...
# 3579                    2280           NEW        PRIVATE         BMW
# 3828                    2255           NEW        PRIVATE  VOLKSWAGEN
# 3594                       0           NEW        PRIVATE      SUBARU
# 3571                    7450           NEW        PRIVATE       ISUZU
# 3612                    3200           NEW        PRIVATE        FORD
#
#                  MODEL  ...        NZ_ASSEMBLED  ORIGINAL_COUNTRY  \
# OBJECTID                ...
# 3442                 A  ...             UNKNOWN         NOT KNOWN
# 3271             TUDOR  ...             UNKNOWN         NOT KNOWN
# 3156              VAS3  ...             UNKNOWN         NOT KNOWN
# 3098      VALIANT AUTO  ...             UNKNOWN         NOT KNOWN
# 3060       LANDCRUISER  ...             UNKNOWN         NOT KNOWN
# ...                ...  ...                 ...               ...
# 3579                M3  ...   IMPORTED BUILT-UP           GERMANY
# 3828            PASSAT  ...   IMPORTED BUILT-UP           GERMANY
# 3594           TRIBECA  ...   IMPORTED BUILT-UP     UNITED STATES
# 3571               NQR  ...  NZ ASSEMBLED/BUILT             JAPAN
# 3612            RANGER  ...   IMPORTED BUILT-UP          THAILAND
#
#           POWER_RATING PREVIOUS_COUNTRY             SUBMODEL  \
# OBJECTID
# 3442                 0             NONE                  NaN
# 3271                 0             NONE                  NaN
# 3156                 0             NONE                  NaN
# 3098                 0             NONE                  NaN
# 3060                 0             NONE                  NaN
# ...                ...              ...                  ...
# 3579               309             NONE   CABRIO 7A 3DR 4.0L
# 3828               220             NONE     R36 6DSG VARIANT
# 3594               189             NONE                  3.6
# 3571               140             NONE        NQR500CVL AMT
# 3612               147             NONE  3.2TD XL DC W/S 4X2
#
#                                    TLA TRANSMISSION_TYPE  \
# OBJECTID
# 3442                 HASTINGS DISTRICT               NaN
# 3271                          AUCKLAND               NaN
# 3156                FAR NORTH DISTRICT               NaN
# 3098                     GORE DISTRICT               NaN
# 3060      CENTRAL HAWKE'S BAY DISTRICT               NaN
# ...                                ...               ...
# 3579                WHANGAREI DISTRICT       7-GEAR AUTO
# 3828              WAIMAKARIRI DISTRICT       6-GEAR AUTO
# 3594           SOUTH TARANAKI DISTRICT       5-GEAR AUTO
# 3571        THAMES-COROMANDEL DISTRICT       6-GEAR AUTO
# 3612                          AUCKLAND     6-GEAR MANUAL
#
#                      VEHICLE_TYPE      VEHICLE_USAGE VEHICLE_YEAR
# OBJECTID
# 3442            PASSENGER CAR/VAN  PRIVATE PASSENGER         1932
# 3271            PASSENGER CAR/VAN  PRIVATE PASSENGER         1933
# 3156                MOTOR CARAVAN  PRIVATE PASSENGER         1977
# 3098      GOODS VAN/TRUCK/UTILITY        OTHER GOODS         1977
# 3060            PASSENGER CAR/VAN              OTHER         1977
# ...                           ...                ...          ...
# 3579            PASSENGER CAR/VAN  PRIVATE PASSENGER         2009
# 3828            PASSENGER CAR/VAN  PRIVATE PASSENGER         2009
# 3594            PASSENGER CAR/VAN  PRIVATE PASSENGER         2009
# 3571                MOTOR CARAVAN  PRIVATE PASSENGER         2010
# 3612      GOODS VAN/TRUCK/UTILITY  PRIVATE PASSENGER         2012
#
# [169 rows x 23 columns]

# %% [markdown]
# ## Step 19. Select the first 7 columns

# %%
df[df.columns[0:7]]
# Out:
#          BASIC_COLOUR      BODY_TYPE  CC_RATING  FIRST_NZ_REGISTRATION_YEAR  \
# OBJECTID
# 3526              RED     SPORTS CAR       1600                        1947
# 3648            WHITE         SALOON       1192                        1962
# 3758            GREEN         SALOON       1285                        1966
# 3442             BLUE         SALOON       3284                        1967
# 3884            WHITE         SALOON       2553                        1970
# ...               ...            ...        ...                         ...
# 3874            BLACK         SALOON       1796                        2012
# 3445           SILVER  STATION WAGON       1794                        2012
# 3349             BLUE      HATCHBACK       2260                        2012
# 3008            BLACK  STATION WAGON       1968                        2012
# 3610           SILVER  STATION WAGON       1490                        2012
#
#           FIRST_NZ_REGISTRATION_MONTH  GROSS_VEHICLE_MASS IMPORT_STATUS
# OBJECTID
# 3526                               11                   0           NEW
# 3648                                6                   0           NEW
# 3758                                8                   0        RE-REG
# 3442                                6                   0           NEW
# 3884                               12                   0           NEW
# ...                               ...                 ...           ...
# 3874                                2                2185           NEW
# 3445                                4                1425          USED
# 3349                                7                1555          USED
# 3008                                4                2185           NEW
# 3610                                3                1515          USED
#
# [1000 rows x 7 columns]

# %% [markdown]
# ## Step 20. Select all columns except the last 3.

# %%
# Hints: use negative to exclude the last 3 columns
df[df.columns[0:-3]]
# Out:
#          BASIC_COLOUR      BODY_TYPE  CC_RATING  FIRST_NZ_REGISTRATION_YEAR  \
# OBJECTID
# 3526              RED     SPORTS CAR       1600                        1947
# 3648            WHITE         SALOON       1192                        1962
# 3758            GREEN         SALOON       1285                        1966
# 3442             BLUE         SALOON       3284                        1967
# 3884            WHITE         SALOON       2553                        1970
# ...               ...            ...        ...                         ...
# 3874            BLACK         SALOON       1796                        2012
# 3445           SILVER  STATION WAGON       1794                        2012
# 3349             BLUE      HATCHBACK       2260                        2012
# 3008            BLACK  STATION WAGON       1968                        2012
# 3610           SILVER  STATION WAGON       1490                        2012
#
#           FIRST_NZ_REGISTRATION_MONTH  GROSS_VEHICLE_MASS IMPORT_STATUS  \
# OBJECTID
# 3526                               11                   0           NEW
# 3648                                6                   0           NEW
# 3758                                8                   0        RE-REG
# 3442                                6                   0           NEW
# 3884                               12                   0           NEW
# ...                               ...                 ...           ...
# 3874                                2                2185           NEW
# 3445                                4                1425          USED
# 3349                                7                1555          USED
# 3008                                4                2185           NEW
# 3610                                3                1515          USED
#
#          INDUSTRY_CLASS           MAKE    MODEL MOTIVE_POWER  NUMBER_OF_AXLES  \
# OBJECTID
# 3526            UNKNOWN          ROVER       16       PETROL                0
# 3648            PRIVATE     VOLKSWAGEN      NaN       PETROL                0
# 3758            PRIVATE     VOLKSWAGEN     1300       PETROL                2
# 3442            PRIVATE           FORD        A       PETROL                0
# 3884            PRIVATE           FORD   ZODIAC       PETROL                0
# ...                 ...            ...      ...          ...              ...
# 3874            PRIVATE  MERCEDES-BENZ        E       PETROL                2
# 3445            PRIVATE         TOYOTA  COROLLA       PETROL                0
# 3349            PRIVATE          MAZDA    AXELA       PETROL                0
# 3008            PRIVATE           AUDI       Q3       DIESEL                0
# 3610            PRIVATE          MAZDA    AXELA       PETROL                0
#
#           NUMBER_OF_SEATS        NZ_ASSEMBLED ORIGINAL_COUNTRY  POWER_RATING  \
# OBJECTID
# 3526                    5             UNKNOWN        NOT KNOWN             0
# 3648                    5             UNKNOWN        NOT KNOWN             0
# 3758                    4  NZ ASSEMBLED/BUILT      NEW ZEALAND             0
# 3442                    5             UNKNOWN        NOT KNOWN             0
# 3884                    5             UNKNOWN        NOT KNOWN             0
# ...                   ...                 ...              ...           ...
# 3874                    5   IMPORTED BUILT-UP          GERMANY           150
# 3445                    5   IMPORTED BUILT-UP            JAPAN             0
# 3349                    5   IMPORTED BUILT-UP            JAPAN             0
# 3008                    5   IMPORTED BUILT-UP          GERMANY           130
# 3610                    5   IMPORTED BUILT-UP            JAPAN             0
#
#          PREVIOUS_COUNTRY            SUBMODEL                 TLA  \
# OBJECTID
# 3526                 NONE                 NaN         NELSON CITY
# 3648                 NONE                 NaN      WAIPA DISTRICT
# 3758                 NONE                 NaN            AUCKLAND
# 3442                 NONE                 NaN   HASTINGS DISTRICT
# 3884                 NONE                 NaN   HASTINGS DISTRICT
# ...                   ...                 ...                 ...
# 3874                 NONE  250 CGI AVANTGARDE  WHANGAREI DISTRICT
# 3445                JAPAN           FIELDER S            AUCKLAND
# 3349                JAPAN                 NaN            AUCKLAND
# 3008                 NONE  2.0 TDI Q S TRONIC            AUCKLAND
# 3610                JAPAN                 NaN            AUCKLAND
#
#          TRANSMISSION_TYPE
# OBJECTID
# 3526                   NaN
# 3648                   NaN
# 3758                   NaN
# 3442                   NaN
# 3884                   NaN
# ...                    ...
# 3874           7-GEAR AUTO
# 3445                   NaN
# 3349                   NaN
# 3008           7-GEAR AUTO
# 3610                   NaN
#
# [1000 rows x 20 columns]

# %% [markdown]
# ## Step 21. Present only the BODY_TYPE from Toyota, Honda and Holden

# %%
make_bodytype = df[['MAKE','BODY_TYPE']]
make_bodytype.index = make_bodytype.MAKE
print(make_bodytype.loc[['HOLDEN', 'HONDA', 'TOYOTA'], ['BODY_TYPE']])
# Out:
#               BODY_TYPE
# MAKE
# HOLDEN          UTILITY
# HOLDEN    STATION WAGON
# HOLDEN          UTILITY
# HOLDEN  FLAT-DECK TRUCK
# HOLDEN          UTILITY
# ...                 ...
# TOYOTA    STATION WAGON
# TOYOTA    STATION WAGON
# TOYOTA    STATION WAGON
# TOYOTA    STATION WAGON
# TOYOTA    STATION WAGON
#
# [294 rows x 1 columns]

# %% [markdown]
# ## Step 22. Estimate the percentage of Toyota cars versus other cars

# %%
print(df.MAKE.value_counts())
array0 = pd.Series(df.MAKE.value_counts())
print('\npercentage of TOYOTA cars versus other cars is', 
      (array0['TOYOTA']/len(df.index))*100,'%')
# Out:
# TOYOTA         158
# MAZDA          140
# NISSAN         105
# FORD            87
# HONDA           83
#               ...
# MOPED            1
# SAKAI            1
# M.T.E.           1
# BRISTOL          1
# CATERPILLAR      1
# Name: MAKE, Length: 70, dtype: int64
#
# percentage of TOYOTA cars versus other cars is 15.8 %

# %% [markdown]
# ## Step 23. Estimate the minimum CC_RATING of each car make

# %%
min_cc = df.groupby(df.MAKE).CC_RATING.min()
min_cc
# Out:
# MAKE
# ALFA ROMEO    2959
# ATLAS            0
# AUDI          1390
# AUSTIN        1275
# BEDFORD       2279
#               ...
# VAUXHALL      1256
# VESPA           49
# VOLKSWAGEN    1192
# VOLVO         1720
# YAMAHA         250
# Name: CC_RATING, Length: 70, dtype: int64

# %% [markdown]
# ## Step 24. For each car make present the percentage of hatchback cars

# %%
#Hints: we filter the cars with BODY_TYPE = 'HATCHBACK', then group them by the MAKE and then count them
# hatchback_cars_df = df[df.BODY_TYPE == 'HATCHBACK']

# (hatchback_cars_df.MAKE.value_counts()/len(df.index))*100

df[df['NODY_TYPE']=='HATCHBACK'].grouby('MAKE')['BODY_COUNT'].count()
print(df.groupby('MAKE')['BODY_TYPE'].count()*100)

# %% [markdown]
# ## Step 26. What is the median CC_RATING for each car make?

# %%
df.groupby('MAKE').CC_RATING.median()
# Out:
# MAKE
# ALFA ROMEO    2959.0
# ATLAS            0.0
# AUDI          2967.0
# AUSTIN        1275.0
# BEDFORD       4223.0
#                ...
# VAUXHALL      1256.0
# VESPA           49.0
# VOLKSWAGEN    1932.0
# VOLVO         1720.0
# YAMAHA         425.0
# Name: CC_RATING, Length: 70, dtype: float64

# %% [markdown]
# ## Step 25. Delete the column `SUBMODEL` and `TLA`

# %%
df.drop(["SUBMODEL", "TLA"], axis=1)
# Out:
#          BASIC_COLOUR      BODY_TYPE  CC_RATING  FIRST_NZ_REGISTRATION_YEAR  \
# OBJECTID
# 3526              RED     SPORTS CAR       1600                        1947
# 3648            WHITE         SALOON       1192                        1962
# 3758            GREEN         SALOON       1285                        1966
# 3442             BLUE         SALOON       3284                        1967
# 3884            WHITE         SALOON       2553                        1970
# ...               ...            ...        ...                         ...
# 3874            BLACK         SALOON       1796                        2012
# 3445           SILVER  STATION WAGON       1794                        2012
# 3349             BLUE      HATCHBACK       2260                        2012
# 3008            BLACK  STATION WAGON       1968                        2012
# 3610           SILVER  STATION WAGON       1490                        2012
#
#           FIRST_NZ_REGISTRATION_MONTH  GROSS_VEHICLE_MASS IMPORT_STATUS  \
# OBJECTID
# 3526                               11                   0           NEW
# 3648                                6                   0           NEW
# 3758                                8                   0        RE-REG
# 3442                                6                   0           NEW
# 3884                               12                   0           NEW
# ...                               ...                 ...           ...
# 3874                                2                2185           NEW
# 3445                                4                1425          USED
# 3349                                7                1555          USED
# 3008                                4                2185           NEW
# 3610                                3                1515          USED
#
#          INDUSTRY_CLASS           MAKE    MODEL  ... NUMBER_OF_AXLES  \
# OBJECTID                                         ...
# 3526            UNKNOWN          ROVER       16  ...               0
# 3648            PRIVATE     VOLKSWAGEN      NaN  ...               0
# 3758            PRIVATE     VOLKSWAGEN     1300  ...               2
# 3442            PRIVATE           FORD        A  ...               0
# 3884            PRIVATE           FORD   ZODIAC  ...               0
# ...                 ...            ...      ...  ...             ...
# 3874            PRIVATE  MERCEDES-BENZ        E  ...               2
# 3445            PRIVATE         TOYOTA  COROLLA  ...               0
# 3349            PRIVATE          MAZDA    AXELA  ...               0
# 3008            PRIVATE           AUDI       Q3  ...               0
# 3610            PRIVATE          MAZDA    AXELA  ...               0
#
#           NUMBER_OF_SEATS        NZ_ASSEMBLED ORIGINAL_COUNTRY POWER_RATING  \
# OBJECTID
# 3526                    5             UNKNOWN        NOT KNOWN            0
# 3648                    5             UNKNOWN        NOT KNOWN            0
# 3758                    4  NZ ASSEMBLED/BUILT      NEW ZEALAND            0
# 3442                    5             UNKNOWN        NOT KNOWN            0
# 3884                    5             UNKNOWN        NOT KNOWN            0
# ...                   ...                 ...              ...          ...
# 3874                    5   IMPORTED BUILT-UP          GERMANY          150
# 3445                    5   IMPORTED BUILT-UP            JAPAN            0
# 3349                    5   IMPORTED BUILT-UP            JAPAN            0
# 3008                    5   IMPORTED BUILT-UP          GERMANY          130
# 3610                    5   IMPORTED BUILT-UP            JAPAN            0
#
#           PREVIOUS_COUNTRY TRANSMISSION_TYPE       VEHICLE_TYPE  \
# OBJECTID
# 3526                  NONE               NaN  PASSENGER CAR/VAN
# 3648                  NONE               NaN  PASSENGER CAR/VAN
# 3758                  NONE               NaN  PASSENGER CAR/VAN
# 3442                  NONE               NaN  PASSENGER CAR/VAN
# 3884                  NONE               NaN  PASSENGER CAR/VAN
# ...                    ...               ...                ...
# 3874                  NONE       7-GEAR AUTO  PASSENGER CAR/VAN
# 3445                 JAPAN               NaN  PASSENGER CAR/VAN
# 3349                 JAPAN               NaN  PASSENGER CAR/VAN
# 3008                  NONE       7-GEAR AUTO  PASSENGER CAR/VAN
# 3610                 JAPAN               NaN  PASSENGER CAR/VAN
#
#               VEHICLE_USAGE VEHICLE_YEAR
# OBJECTID
# 3526      PRIVATE PASSENGER         1947
# 3648      PRIVATE PASSENGER         1962
# 3758      PRIVATE PASSENGER         1966
# 3442      PRIVATE PASSENGER         1932
# 3884      PRIVATE PASSENGER         1965
# ...                     ...          ...
# 3874      PRIVATE PASSENGER         2012
# 3445      PRIVATE PASSENGER         2006
# 3349      PRIVATE PASSENGER         2005
# 3008      PRIVATE PASSENGER         2012
# 3610      PRIVATE PASSENGER         2006
#
# [1000 rows x 21 columns]
